# %% [markdown]
# #**Data Understanding**

# %%
import pandas as pd
file_path = "/content/drive/MyDrive/Customer Loyalty/PMC Hospital Infrastructure.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#   City Name                      Zone Name              Ward Name  Zone No.  \
# 0      Pune      kasba - vishrambagwada WO             Ambil Odha       5.0
# 1      Pune               Aundh - Baner WO                  Aundh       2.0
# 2      Pune               Aundh - Baner WO                 Bopodi       2.0
# 3      Pune  Ghole Road - Shivaji Nagar WO  Shivaji Nagar Station       2.0
# 4      Pune          Hadapsar - Mundhwa WO               Hadapsar       4.0
#
#    Ward No.                                      Facility Name  \
# 0       NaN  Late Matoshri Ramabai Ambedkar Maternity Home,...
# 1       NaN                   Aundh Kuti Maternity Home, Aundh
# 2       NaN  Late Draupadabai Murlidhar Khedekar Maternity ...
# 3       NaN                       Dr. Dalvi, PMC Joint Project
# 4       NaN     Late Anna Saheb Magar Maternity Home, Hadapsar
#
#   Type  (Hospital / Nursing Home / Lab)  Class : (Public / Private)  \
# 0             Hospital (Maternity Home)                      Public
# 1             Hospital (Maternity Home)                      Public
# 2             Hospital (Maternity Home)                      Public
# 3             Hospital (Maternity Home)                      Public
# 4             Hospital (Maternity Home)                      Public
#
#   Pharmacy Available : Yes/No  Number of Beds in Emergency Wards   \
# 0                         Yes                                   0
# 1                         Yes                                   0
# 2                         Yes                                   0
# 3                         Yes                                   0
# 4                         Yes                                   0
#
#    Number of Beds in facility type  Number of Doctors / Physicians  \
# 0                               10                               2
# 1                               14                               2
# 2                               16                               2
# 3                               30                               4
# 4                               20                               2
#
#    Number of Nurses  Number of Midwives Professional   \
# 0                 4                                 1
# 1                 5                                 2
# 2                 4                                 9
# 3                 7                                 9
# 4                 3                                 6
#
#    Average Monthly Patient Footfall Ambulance Service Available  \
# 0                              4500                         Yes
# 1                              2500                         Yes
# 2                              1900                         Yes
# 3                              2400                         Yes
# 4                              4500                         Yes
#
#    Count of Ambulance
# 0                   1
# 1                   1
# 2                   1
# 3                   2
# 4                   1

# %%
df.shape
# Out:
# (737, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 737 entries, 0 to 736
# Data columns (total 17 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   City Name                              737 non-null    object
#  1   Zone Name                              705 non-null    object
#  2   Ward Name                              735 non-null    object
#  3   Zone No.                               692 non-null    float64
#  4   Ward No.                               0 non-null      float64
#  5   Facility Name                          737 non-null    object
#  6   Type  (Hospital / Nursing Home / Lab)  737 non-null    object
#  7    Class : (Public / Private)            737 non-null    object
#  8   Pharmacy Available : Yes/No            737 non-null    object
#  9   Number of Beds in Emergency Wards      737 non-null    int64
#  10  Number of Beds in facility type        737 non-null    int64
#  11  Number of Doctors / Physicians         737 non-null    int64
#  12  Number of Nurses                       737 non-null    int64
#  13  Number of Midwives Professional        737 non-null    int64
#  14  Average Monthly Patient Footfall       737 non-null    int64
#  15  Ambulance Service Available            737 non-null    object
#  16  Count of Ambulance                     737 non-null    int64
# dtypes: float64(2), int64(7), object(8)
# memory usage: 98.0+ KB

# %%
df.rename(columns={
    'Type  (Hospital / Nursing Home / Lab)': 'Type',
    'Pharmacy Available : Yes/No': 'Pharmacy',
    'Class : (Public / Private)': 'Class'
}, inplace=True)

# %%
df.columns
# Out:
# Index(['City Name', 'Zone Name', 'Ward Name', 'Zone No.', 'Ward No.',
#        'Facility Name', 'Type', ' Class : (Public / Private)', 'Pharmacy',
#        'Number of Beds in Emergency Wards ', 'Number of Beds in facility type',
#        'Number of Doctors / Physicians', 'Number of Nurses',
#        'Number of Midwives Professional ', 'Average Monthly Patient Footfall',
#        'Ambulance Service Available', 'Count of Ambulance'],
#       dtype='object')

# %%
df.head(2)
# Out:
#   City Name                  Zone Name   Ward Name  Zone No.  Ward No.  \
# 0      Pune  kasba - vishrambagwada WO  Ambil Odha       5.0       NaN
# 1      Pune           Aundh - Baner WO       Aundh       2.0       NaN
#
#                                        Facility Name  \
# 0  Late Matoshri Ramabai Ambedkar Maternity Home,...
# 1                   Aundh Kuti Maternity Home, Aundh
#
#                         Type  Class : (Public / Private) Pharmacy  \
# 0  Hospital (Maternity Home)                      Public      Yes
# 1  Hospital (Maternity Home)                      Public      Yes
#
#    Number of Beds in Emergency Wards   Number of Beds in facility type  \
# 0                                   0                               10
# 1                                   0                               14
#
#    Number of Doctors / Physicians  Number of Nurses  \
# 0                               2                 4
# 1                               2                 5
#
#    Number of Midwives Professional   Average Monthly Patient Footfall  \
# 0                                 1                              4500
# 1                                 2                              2500
#
#   Ambulance Service Available  Count of Ambulance
# 0                         Yes                   1
# 1                         Yes                   1

# %%
df.isnull().sum()
# Out:
# City Name                               0
# Zone Name                              32
# Ward Name                               2
# Zone No.                               45
# Ward No.                              737
# Facility Name                           0
# Type                                    0
#  Class : (Public / Private)             0
# Pharmacy                                0
# Number of Beds in Emergency Wards       0
# Number of Beds in facility type         0
# Number of Doctors / Physicians          0
# Number of Nurses                        0
# Number of Midwives Professional         0
# Average Monthly Patient Footfall        0
# Ambulance Service Available             0
# Count of Ambulance                      0
# dtype: int64

# %%
df = df.drop('Ward No.', axis=1)
display(df.head())
# Out:
#   City Name                      Zone Name              Ward Name  Zone No.  \
# 0      Pune      kasba - vishrambagwada WO             Ambil Odha       5.0
# 1      Pune               Aundh - Baner WO                  Aundh       2.0
# 2      Pune               Aundh - Baner WO                 Bopodi       2.0
# 3      Pune  Ghole Road - Shivaji Nagar WO  Shivaji Nagar Station       2.0
# 4      Pune          Hadapsar - Mundhwa WO               Hadapsar       4.0
#
#                                        Facility Name  \
# 0  Late Matoshri Ramabai Ambedkar Maternity Home,...
# 1                   Aundh Kuti Maternity Home, Aundh
# 2  Late Draupadabai Murlidhar Khedekar Maternity ...
# 3                       Dr. Dalvi, PMC Joint Project
# 4     Late Anna Saheb Magar Maternity Home, Hadapsar
#
#                         Type  Class : (Public / Private) Pharmacy  \
# 0  Hospital (Maternity Home)                      Public      Yes
# 1  Hospital (Maternity Home)                      Public      Yes
# 2  Hospital (Maternity Home)                      Public      Yes
# 3  Hospital (Maternity Home)                      Public      Yes
# 4  Hospital (Maternity Home)                      Public      Yes
#
#    Number of Beds in Emergency Wards   Number of Beds in facility type  \
# 0                                   0                               10
# 1                                   0                               14
# 2                                   0                               16
# 3                                   0                               30
# 4                                   0                               20
#
#    Number of Doctors / Physicians  Number of Nurses  \
# 0                               2                 4
# 1                               2                 5
# 2                               2                 4
# 3                               4                 7
# 4                               2                 3
#
#    Number of Midwives Professional   Average Monthly Patient Footfall  \
# 0                                 1                              4500
# 1                                 2                              2500
# 2                                 9                              1900
# 3                                 9                              2400
# 4                                 6                              4500
#
#   Ambulance Service Available  Count of Ambulance
# 0                         Yes                   1
# 1                         Yes                   1
# 2                         Yes                   1
# 3                         Yes                   2
# 4                         Yes                   1

# %%
# Strip whitespace from object columns
for col in df.select_dtypes(include='object').columns:
    df[col] = df[col].str.strip()

# Convert relevant columns to lowercase
for col in ['City Name', 'Zone Name', 'Ward Name', 'Facility Name', 'Type', ' Class : (Public / Private)', 'Pharmacy', 'Ambulance Service Available']:
    df[col] = df[col].str.lower()

# Replace inconsistent values in 'Type' column
type_replacements = {
    'hospital (maternity home)': 'hospital',
    'nursing home': 'nursing home',
    'lab': 'lab',
    'maternity': 'hospital',
    'general': 'hospital',
    'maternity + general': 'hospital',
    'opthalmology': 'hospital',
    'dental': 'hospital',
    'speciality': 'hospital',
    'ortho': 'hospital'
}
df['Type'] = df['Type'].replace(type_replacements)

# Replace inconsistent values in 'Pharmacy' column
pharmacy_replacements = {
    'yes': 'yes',
    'no': 'no',
    'n.a.': 'no' # Assuming N.A. means no pharmacy available
}
df['Pharmacy'] = df['Pharmacy'].replace(pharmacy_replacements)


# Replace inconsistent values in 'Ambulance Service Available' column
ambulance_replacements = {
    'yes': 'yes',
    'no': 'no',
    'n.a.': 'no' # Assuming N.A. means no ambulance service available
}
df['Ambulance Service Available'] = df['Ambulance Service Available'].replace(ambulance_replacements)

display(df.head())
# Out:
#   City Name                      Zone Name              Ward Name  Zone No.  \
# 0      pune      kasba - vishrambagwada wo             ambil odha       5.0
# 1      pune               aundh - baner wo                  aundh       2.0
# 2      pune               aundh - baner wo                 bopodi       2.0
# 3      pune  ghole road - shivaji nagar wo  shivaji nagar station       2.0
# 4      pune          hadapsar - mundhwa wo               hadapsar       4.0
#
#                                        Facility Name      Type  \
# 0  late matoshri ramabai ambedkar maternity home,...  hospital
# 1                   aundh kuti maternity home, aundh  hospital
# 2  late draupadabai murlidhar khedekar maternity ...  hospital
# 3                       dr. dalvi, pmc joint project  hospital
# 4     late anna saheb magar maternity home, hadapsar  hospital
#
#    Class : (Public / Private) Pharmacy  Number of Beds in Emergency Wards   \
# 0                      public      yes                                   0
# 1                      public      yes                                   0
# 2                      public      yes                                   0
# 3                      public      yes                                   0
# 4                      public      yes                                   0
#
#    Number of Beds in facility type  Number of Doctors / Physicians  \
# 0                               10                               2
# 1                               14                               2
# 2                               16                               2
# 3                               30                               4
# 4                               20                               2
#
#    Number of Nurses  Number of Midwives Professional   \
# 0                 4                                 1
# 1                 5                                 2
# 2                 4                                 9
# 3                 7                                 9
# 4                 3                                 6
#
#    Average Monthly Patient Footfall Ambulance Service Available  \
# 0                              4500                         yes
# 1                              2500                         yes
# 2                              1900                         yes
# 3                              2400                         yes
# 4                              4500                         yes
#
#    Count of Ambulance
# 0                   1
# 1                   1
# 2                   1
# 3                   2
# 4                   1

# %% [markdown]
# #**Exploratory Data Analysis**

# %%
df.head(3)
# Out:
#   City Name                  Zone Name   Ward Name  Zone No.  \
# 0      pune  kasba - vishrambagwada wo  ambil odha       5.0
# 1      pune           aundh - baner wo       aundh       2.0
# 2      pune           aundh - baner wo      bopodi       2.0
#
#                                        Facility Name      Type  \
# 0  late matoshri ramabai ambedkar maternity home,...  hospital
# 1                   aundh kuti maternity home, aundh  hospital
# 2  late draupadabai murlidhar khedekar maternity ...  hospital
#
#    Class : (Public / Private) Pharmacy  Number of Beds in Emergency Wards   \
# 0                      public      yes                                   0
# 1                      public      yes                                   0
# 2                      public      yes                                   0
#
#    Number of Beds in facility type  Number of Doctors / Physicians  \
# 0                               10                               2
# 1                               14                               2
# 2                               16                               2
#
#    Number of Nurses  Number of Midwives Professional   \
# 0                 4                                 1
# 1                 5                                 2
# 2                 4                                 9
#
#    Average Monthly Patient Footfall Ambulance Service Available  \
# 0                              4500                         yes
# 1                              2500                         yes
# 2                              1900                         yes
#
#    Count of Ambulance
# 0                   1
# 1                   1
# 2                   1

# %%
df.describe()
# Out:
#          Zone No.  Number of Beds in Emergency Wards   \
# count  692.000000                          737.000000
# mean     3.013006                            2.557666
# std      1.401303                            1.574163
# min      1.000000                            0.000000
# 25%      2.000000                            1.000000
# 50%      3.000000                            3.000000
# 75%      4.000000                            4.000000
# max      5.000000                            5.000000
#
#        Number of Beds in facility type  Number of Doctors / Physicians  \
# count                       737.000000                      737.000000
# mean                         21.721845                        1.956581
# std                          63.657392                        0.443263
# min                           0.000000                        1.000000
# 25%                           4.000000                        2.000000
# 50%                           7.000000                        2.000000
# 75%                          15.000000                        2.000000
# max                         831.000000                       10.000000
#
#        Number of Nurses  Number of Midwives Professional   \
# count        737.000000                        737.000000
# mean           2.031208                          2.959294
# std            2.486453                          1.105064
# min            0.000000                          0.000000
# 25%            2.000000                          3.000000
# 50%            2.000000                          3.000000
# 75%            2.000000                          3.000000
# max           64.000000                         23.000000
#
#        Average Monthly Patient Footfall  Count of Ambulance
# count                        737.000000          737.000000
# mean                        2550.597015            0.953867
# std                          789.211681            0.300433
# min                           50.000000            0.000000
# 25%                         2550.000000            1.000000
# 50%                         2550.000000            1.000000
# 75%                         2550.000000            1.000000
# max                        18000.000000            4.000000

# %%
df.select_dtypes(include='object').describe()
# Out:
#        City Name Zone Name      Ward Name         Facility Name     Type  \
# count        737       705            735                   737      737
# unique         1        18             80                   701       36
# top         pune         2  kasba-vishram  dhanwantari hospital  mat+gen
# freq         737       161             81                     5      278
#
#         Class : (Public / Private) Pharmacy Ambulance Service Available
# count                          737      737                         737
# unique                           2        2                           2
# top                        private       no                          no
# freq                           663      603                         669

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1️⃣ Visualize the distribution of 'Type' with a new palette
plt.figure(figsize=(10, 6))
sns.countplot(
    data=df,
    y='Type',
    order=df['Type'].value_counts().index,
    palette='magma'   # different color scheme
)
plt.title('Distribution of Facility Types')
plt.xlabel('Count')
plt.ylabel('Facility Type')
plt.show()
# Out:
# /tmp/ipython-input-13-4142690094.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %%
# Visualize the distribution of 'Class : (Public / Private)'
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x=' Class : (Public / Private)')
plt.title('Distribution of Facility Class (Public/Private)')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Pharmacy')
plt.title('Distribution of Facilities with Pharmacy Available')
plt.xlabel('Pharmacy Available')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Ambulance Service Available')
plt.title('Distribution of Facilities with Ambulance Service Available')
plt.xlabel('Ambulance Service Available')
plt.ylabel('Count')
plt.show()

# %%
average_beds_by_type = df.groupby('Type')['Number of Beds in facility type'].mean().round(1).sort_values(ascending=False)
display(average_beds_by_type)
# Out:
# Type
# hospital (general)                        450.0
# hospital (infectious disease)             200.0
# homeopathic                               100.0
# aurvedic                                   70.2
# cardiology                                 57.0
# hospital                                   52.2
# canser                                     50.0
# specility both                             31.0
# mat+orthopedics                            27.0
# ortho.                                     26.4
# both                                       25.0
# urology                                    23.5
# pediatric                                  15.3
# ayurved & panchkarma                       15.0
# mat+gen                                    13.7
# genral                                     11.8
# sergical                                   10.0
# gen                                         9.4
# mat+ gen                                    7.7
# opthlm                                      6.7
# opthalmology+ent                            6.0
# mat+   gen                                  5.0
# general+ ortho                              5.0
# cardiologist                                5.0
# ivf                                         4.0
# mat+ent                                     4.0
# opthalm                                     4.0
# opthal                                      3.3
# ent                                         2.4
# opth.                                       2.2
# optholm                                     2.0
# optahl                                      2.0
# optahlm                                     1.0
# dispensary (opd - mobile clinic)            0.0
# dispensary (opd)                            0.0
# dispensary (opd + immunization centre)      0.0
# Name: Number of Beds in facility type, dtype: float64

# %%
plt.figure(figsize=(10, 6))
average_beds_by_type.head().plot(kind='barh')
plt.title('Top 5 Facility Types by Average Number of Beds')
plt.xlabel('Average Number of Beds')
plt.ylabel('Facility Type')
plt.gca().invert_yaxis() # To display the highest average at the top
plt.show()

# %%
average_footfall_by_type = df.groupby('Type')['Average Monthly Patient Footfall'].mean().round(1).sort_values(ascending=False)
display(average_footfall_by_type)
# Out:
# Type
# hospital (general)                        18000.0
# hospital (infectious disease)              4000.0
# hospital                                   2621.1
# aurvedic                                   2550.0
# canser                                     2550.0
# both                                       2550.0
# ayurved & panchkarma                       2550.0
# cardiologist                               2550.0
# general+ ortho                             2550.0
# cardiology                                 2550.0
# gen                                        2550.0
# ent                                        2550.0
# genral                                     2550.0
# ivf                                        2550.0
# mat+   gen                                 2550.0
# homeopathic                                2550.0
# mat+ gen                                   2550.0
# mat+orthopedics                            2550.0
# mat+gen                                    2550.0
# mat+ent                                    2550.0
# opthalmology+ent                           2550.0
# opthlm                                     2550.0
# optholm                                    2550.0
# optahl                                     2550.0
# optahlm                                    2550.0
# opth.                                      2550.0
# opthal                                     2550.0
# opthalm                                    2550.0
# pediatric                                  2550.0
# sergical                                   2550.0
# specility both                             2550.0
# ortho.                                     2550.0
# urology                                    2550.0
# dispensary (opd + immunization centre)     2200.0
# dispensary (opd)                           2101.8
# dispensary (opd - mobile clinic)            833.3
# Name: Average Monthly Patient Footfall, dtype: float64

# %%
plt.figure(figsize=(10, 6))
average_footfall_by_type.head().plot(kind='barh')
plt.title('Top 5 Facility Types by Average Monthly Patient Footfall')
plt.xlabel('Average Monthly Patient Footfall')
plt.ylabel('Facility Type')
plt.gca().invert_yaxis() # To display the highest average at the top
plt.show()
